# %%
paths = ['/Library/Python/2.7/site-packages/mrjob-0.2.4-py2.7.egg',
'/Library/Python/2.7/site-packages/simplejson-3.6.3-py2.7-macosx-10.9-intel.egg',
'/Library/Python/2.7/site-packages/PyYAML-3.11-py2.7-macosx-10.9-intel.egg',
'/Library/Python/2.7/site-packages/boto-2.32.1-py2.7.egg',
'/Library/Python/2.7/site-packages/Pattern-2.6-py2.7.egg',
'/Library/Python/2.7/site-packages/python_sql-0.4-py2.7.egg',
'/Library/Python/2.7/site-packages/ipython_sql-0.3.4-py2.7.egg',
'/Library/Python/2.7/site-packages/sqlparse-0.1.13-py2.7.egg',
'/Library/Python/2.7/site-packages/SQLAlchemy-0.9.8-py2.7-macosx-10.10-intel.egg',
'/Library/Python/2.7/site-packages/prettytable-0.7.2-py2.7.egg',
'/Library/Python/2.7/site-packages',
'/Library/Python/2.7/site-packages/db.py-0.3.1-py2.7.egg']

import sys
for path in paths:
    sys.path.append(path)

# %%
from db import DemoDB

# %%
db = DemoDB()
# Out:
# Indexing schema. This will take a second...finished!
# Refreshing schema. Please wait...done!

# %% [markdown]
# ##Show the tables in the database

# %%
db.tables
# Out:
# +---------------+----------------------------------------------------------------------------------+
# | Table         | Columns                                                                          |
# +---------------+----------------------------------------------------------------------------------+
# | Album         | AlbumId, Title, ArtistId                                                         |
# | Artist        | ArtistId, Name                                                                   |
# | Customer      | CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalC |
# |               | ode, Phone, Fax, Email, SupportRepId                                             |
# | Employee      | EmployeeId, LastName, FirstName, Title, ReportsTo, BirthDate, HireDate, Address, |
# |               |  City, State, Country, PostalCode, Phone, Fax, Email                             |
# ...

# %% [markdown]
# ##Show the Employee table

# %%
db.tables.Employee
# Out:
# +---------------------------------------------------------------------------------------------+
# |                                           Employee                                          |
# +------------+--------------+---------------------+-------------------------------------------+
# | Column     | Type         | Foreign Keys        | Reference Keys                            |
# +------------+--------------+---------------------+-------------------------------------------+
# | EmployeeId | INTEGER      |                     | Customer.SupportRepId, Employee.ReportsTo |
# | LastName   | NVARCHAR(20) |                     |                                           |
# | FirstName  | NVARCHAR(20) |                     |                                           |
# | Title      | NVARCHAR(30) |                     |                                           |
# | ReportsTo  | INTEGER      | Employee.EmployeeId |                                           |
# ...

# %% [markdown]
# ##The first few items in Playlist table

# %%
db.tables.Playlist.head()
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music
# 5           6  Audiobooks

# %% [markdown]
# ##Count of unique PlaylistId in the table Playlist

# %%
db.tables.Playlist.PlaylistId.unique().count()
# Out:
# 18

# %% [markdown]
# ##Get a sample of Employee table

# %%
db.tables.Employee.sample()
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           3   Peacock      Jane  Sales Support Agent          2
# 1           1     Adams    Andrew      General Manager        NaN
# 2           6  Mitchell   Michael           IT Manager          1
# 3           2   Edwards     Nancy        Sales Manager          1
# 4           8  Callahan     Laura             IT Staff          6
# 5           7      King    Robert             IT Staff          6
# 6           4      Park  Margaret  Sales Support Agent          2
# 7           5   Johnson     Steve  Sales Support Agent          2
#
#              BirthDate             HireDate                      Address  \
# 0  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 1  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 2  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 3  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# ...

# %% [markdown]
# ##Find columns with names like '*Name'

# %%
db.find_column('*Name*')
# Out:
# +-----------+-------------+---------------+
# | Table     | Column Name | Type          |
# +-----------+-------------+---------------+
# | Artist    |     Name    | NVARCHAR(120) |
# | Customer  |  FirstName  | NVARCHAR(40)  |
# | Customer  |   LastName  | NVARCHAR(20)  |
# | Employee  |  FirstName  | NVARCHAR(20)  |
# | Employee  |   LastName  | NVARCHAR(20)  |
# | Genre     |     Name    | NVARCHAR(120) |
# | MediaType |     Name    | NVARCHAR(120) |
# | Playlist  |     Name    | NVARCHAR(120) |
# | Track     |     Name    | NVARCHAR(200) |
# +-----------+-------------+---------------+

# %% [markdown]
# ##Find columns with type of INTEGER

# %%
db.find_column('*','INTEGER')
# Out:
# +---------------+---------------+---------+
# | Table         |  Column Name  | Type    |
# +---------------+---------------+---------+
# | Album         |    AlbumId    | INTEGER |
# | Album         |    ArtistId   | INTEGER |
# | Artist        |    ArtistId   | INTEGER |
# | Customer      |  SupportRepId | INTEGER |
# | Customer      |   CustomerId  | INTEGER |
# | Employee      |   EmployeeId  | INTEGER |
# | Employee      |   ReportsTo   | INTEGER |
# | Genre         |    GenreId    | INTEGER |
# | Invoice       |   InvoiceId   | INTEGER |
# | Invoice       |   CustomerId  | INTEGER |
# | InvoiceLine   |   InvoiceId   | INTEGER |
# | InvoiceLine   |    TrackId    | INTEGER |
# | InvoiceLine   |    Quantity   | INTEGER |
# | InvoiceLine   | InvoiceLineId | INTEGER |
# | MediaType     |  MediaTypeId  | INTEGER |
# | Playlist      |   PlaylistId  | INTEGER |
# | PlaylistTrack |    TrackId    | INTEGER |
# | PlaylistTrack |   PlaylistId  | INTEGER |
# ...

# %% [markdown]
# ##Find tables with names like 'A*'

# %%
db.find_table('A*')
# Out:
# +--------+--------------------------+
# | Table  | Columns                  |
# +--------+--------------------------+
# | Album  | AlbumId, Title, ArtistId |
# | Artist | ArtistId, Name           |
# +--------+--------------------------+

# %% [markdown]
# ##Query on tables

# %%
db.query('SELECT * FROM Album LIMIT 10;')
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3
# 5        6                     Jagged Little Pill         4
# 6        7                               Facelift         5
# 7        8                         Warner 25 Anos         6
# 8        9         Plays Metallica By Four Cellos         7
# 9       10                             Audioslave         8

# %% [markdown]
# #Connect to a database

# %%
from db import DB

# %%
db = DB(username='root',password='nlJ%p89E',hostname='localhost',dbtype='mysql')
# Out:
# Refreshing schema. Please wait...done!

# %%
db.tables
# Out:
# +---------------------+----------------------------------------------------------------------------------+
# | Table               | Columns                                                                          |
# +---------------------+----------------------------------------------------------------------------------+
# | AllstarFull         | playerID, yearID, gameNum, gameID, teamID, lgID, GP, startingPos                 |
# | Appearances         | yearID, teamID, lgID, playerID, G_all, GS, G_batting, G_defense, G_p, G_c, G_1b, |
# |                     |  G_2b, G_3b, G_ss, G_lf, G_cf, G_rf, G_of, G_dh, G_ph, G_pr                      |
# | AwardsManagers      | playerID, awardID, yearID, lgID, tie, notes                                      |
# | AwardsPlayers       | playerID, awardID, yearID, lgID, tie, notes                                      |
# | AwardsShareManagers | awardID, yearID, lgID, playerID, pointsWon, pointsMax, votesFirst                |
# ...

# %%
db.tables.Appearances
# Out:
# +-----------------------------------------------------+
# |                     Appearances                     |
# +-----------+---------+--------------+----------------+
# | Column    | Type    | Foreign Keys | Reference Keys |
# +-----------+---------+--------------+----------------+
# | yearID    | int     |              |                |
# | teamID    | varchar |              |                |
# | lgID      | varchar |              |                |
# | playerID  | varchar |              |                |
# | G_all     | int     |              |                |
# | GS        | int     |              |                |
# | G_batting | int     |              |                |
# | G_defense | int     |              |                |
# | G_p       | int     |              |                |
# | G_c       | int     |              |                |
# | G_1b      | int     |              |                |
# | G_2b      | int     |              |                |
# ...

# %% [markdown]
# ##Save a profile

# %%
db.save_credentials(profile='local_jw')

# %% [markdown]
# ##List profiles

# %%
from db import list_profiles

# %%
list_profiles()
# Out:
# {'local_jw': {u'dbname': None,
#   u'dbtype': u'mysql',
#   u'filename': None,
#   u'hostname': u'localhost',
#   u'limit': 1000,
#   u'password': u'nlJ%p89E',
#   u'port': 3306,
#   u'schemas': None,
#   u'username': u'root'}}

# %% [markdown]
# ##Connect from a profile

# %%
db = DB(profile='local_jw')
# Out:
# Refreshing schema. Please wait...done!
